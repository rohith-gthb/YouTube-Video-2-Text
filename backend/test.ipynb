# %%
import requests
import random
import re 
import json

# %%
import requests
 
response = requests.get(
  "https://proxy.webshare.io/api/v3/proxy/config?plan_id=12471125",
  headers={ "Authorization": "Token 1apykvicghxau1pthui11mx5rl7acvchihzruivs" }
)
 
response.json()
# Out:
# {'request_timeout': 28800,
#  'request_idle_timeout': 900,
#  'ip_authorization_country_codes': None,
#  'auto_replace_invalid_proxies': True,
#  'auto_replace_low_country_confidence_proxies': False,
#  'auto_replace_out_of_rotation_proxies': False,
#  'auto_replace_failed_site_check_proxies': False,
#  'proxy_list_download_token': 'udriypwseacsuooiqgkclcvfaxaqgjmjpmnquiel'}

# %%
proxy_response = requests.get(
        "https://proxy.webshare.io/api/v2/proxy/list/?mode=direct&page=1&page_size=25",
        headers={ "Authorization": "Token udriypwseacsuooiqgkclcvfaxaqgjmjpmnquiel" }
    )

# %%
proxy_response
# Out:
# <Response [401]>

# %%
import random 
def get_random_proxy():
    proxy_response = requests.get(
        "https://proxy.webshare.io/api/v2/proxy/list/?mode=direct&page=1&page_size=25",
        headers={ "Authorization": "Token udriypwseacsuooiqgkclcvfaxaqgjmjpmnquiel" }
    ) 
    proxy_list = (json.loads(proxy_response.text)['results'])
    p = random.choice(proxy_list)
    # The full URL including credentials
    proxy_url = f"http://{p['username']}:{p['password']}@{p['proxy_address']}:{p['port']}"
    
    # RETURN A DICTIONARY, NOT A STRING
    return {
        "http": proxy_url,
        "https": proxy_url
    }


get_random_proxy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 19
#      12     # RETURN A DICTIONARY, NOT A STRING
#      13     return {
#      14         "http": proxy_url,
#      15         "https": proxy_url
#      16     }
# ---> 19 get_random_proxy()
#
# Cell In[39], line 7, in get_random_proxy()
#       2 def get_random_proxy():
#       3     proxy_response = requests.get(
#       4         "https://proxy.webshare.io/api/v2/proxy/list/?mode=direct&page=1&page_size=25",
#       5         headers={ "Authorization": "Token udriypwseacsuooiqgkclcvfaxaqgjmjpmnquiel" }
#       6     )
# ----> 7     proxy_list = (json.loads(proxy_response.text)['results'])
#       8     p = random.choice(proxy_list)
#       9     # The full URL including credentials
#
# KeyError: 'results'

# %%
proxy_response = requests.get(
    "https://proxy.webshare.io/api/v2/subscription/",
    headers={ "Authorization": "Token 1apykvicghxau1pthui11mx5rl7acvchihzruivs" }
)

# %%
data = json.loads(proxy_response.text)
print(json.dumps(data, indent=4))
# Out:
# {
#     "detail": "Invalid token."
# }

# %%
import re 

url = "https://www.youtube.com/watch?v=cESaIUWoCJQ"

def extract_video_id(url: str):
    """Extracts the video ID from a YouTube URL."""
    patterns = [
        r"(?:v=|\/)([0-9A-Za-z_-]{11}).*",
        r"youtu\.be\/([0-9A-Za-z_-]{11})",
        r"embed\/([0-9A-Za-z_-]{11})",
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

video_id = extract_video_id(url)
print(video_id)
# Out:
# cESaIUWoCJQ

# %%
url
# Out:
# 'https://www.youtube.com/watch?v=cESaIUWoCJQ'

# %%
response = requests.get(url, proxies=get_random_proxy())
response.text
# Out:
# '<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="lt-LT" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="uboAIyXGJf1q9INcrxIl2g">window.WIZ_global_data = {"AfY8Hf":true,"HiPsbb":0,"MUE6Ne":"youtube_web","MuJWjd":true,"UUFaWc":"%.@.null,1000,2]","cfb2h":"youtube.web-front-end-critical_20251221.10_p0","fPDxwd":[],"hsFLT":"%.@.null,1000,2]","iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"772657768":true,"513659523":false,"568333945":true,"1331761403":false,"651175828":false,"722764542":false,"748402145":false,"748402146":false,"748402147":true,"824648567":true,"824656860":false,"333098724":false},"u4g7r":"%.@.null,1,2]","vJQk6":false,"xnI9P":true,"xwAfE":true,"yFnxrf":2486};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVly
# ...

# %%
import traceback
import requests
from bs4 import BeautifulSoup

def get_video_info(video_id: str):
    """Fetches video metadata using requests and BeautifulSoup (Safer Alternative)."""
    url = f"https://www.youtube.com/watch?v={video_id}"

    try:
        response = requests.get(url, proxies=get_random_proxy())
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract title
        title = ""
        title_tag = soup.find("meta", property="og:title")
        if title_tag:
            title = title_tag["content"]
        
        # Extract thumbnail
        thumbnail = f"https://img.youtube.com/vi/{video_id}/maxresdefault.jpg"
            
        # Extract author
        author = ""
        author_tag = soup.find("link", itemprop="name")
        if author_tag:
            author = author_tag["content"]
        elif soup.find("span", itemprop="author"):
            author = soup.find("span", itemprop="author").find("link", itemprop="name")["content"]

        return {
            "title": title or "Unknown Title",
            "thumbnail": thumbnail or f"https://img.youtube.com/vi/{video_id}/maxresdefault.jpg",
            "author": author or "Unknown Author",
        }
    except Exception as e:
        print(f"Error fetching metadata: {traceback.format_exc()}")
        return None

get_video_info(video_id)
# Out:
# {'title': 'Unknown Title',
#  'thumbnail': 'https://img.youtube.com/vi/cESaIUWoCJQ/maxresdefault.jpg',
#  'author': 'Unknown Author'}

# %%
WEBSHARE_USER = "znxcztag"
WEBSHARE_PASS = "hi7oonlzr7ea"

# %%
def get_webshare_config():
    """Returns a WebshareProxyConfig object for rotating residential proxies."""
    return WebshareProxyConfig(
        proxy_username=WEBSHARE_USER,
        proxy_password=WEBSHARE_PASS,
        filter_ip_locations=["US", "GB", "DE"]
    )

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.proxies import WebshareProxyConfig

ytt_api = YouTubeTranscriptApi(
    proxy_config=WebshareProxyConfig(
        proxy_username=WEBSHARE_USER,
        proxy_password=WEBSHARE_PASS,
    )
)

# %%
proxy_config

# %%
c=0

while c<3:
    try:
        proxy_config = get_webshare_config()
        api = YouTubeTranscriptApi(proxy_config=proxy_config)
        transcript_list = api.fetch(video_id)
    except :
        c+=1
    
print(transcript_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 11
#       8     except :
#       9         c+=1
# ---> 11 print(transcript_list)
#
# NameError: name 'transcript_list' is not defined

# %%
transcript_list
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='Another day, another startup. Recently,', start=0.0, duration=5.04), FetchedTranscriptSnippet(text="I moved to Malaysia and from there, I've", start=2.879, duration=3.761), FetchedTranscriptSnippet(text='pretty much been spending most of my', start=5.04, duration=3.92), FetchedTranscriptSnippet(text="time coding my latest project. And it's", start=6.64, duration=4.16), FetchedTranscriptSnippet(text='been super fun hacking away at something', start=8.96, duration=3.36), FetchedTranscriptSnippet(text="new again. And luckily, I've been", start=10.8, duration=3.28), FetchedTranscriptSnippet(text='documenting the whole journey from', start=12.32, duration=3.6), FetchedTranscriptSnippet(text='coming up with the app idea to building', start=14.08, duration=3.6), FetchedTranscriptSnippet(text='the app to getting that first paying', start=15.92, duration=3.519), FetchedTranscriptSnippet(text="customer. In this video, I'll show you", s
# ...

# %%
try:
    video_info = get_video_info(video_id)
    formatted_transcript = []
    full_text = ""
    for entry in transcript_list:
        # Robust cleaning: Remove '>>', '>>>', [Music], (Laughter), etc.
        text = entry.text
        # Remove HTML entities if any
        text = text.replace("&gt;&gt;", "").replace("&gt;", "")
        # Remove literal >> and variations
        text = re.sub(r'>>+', '', text) 
        text = re.sub(r'\[.*?\]', '', text) # Remove [Music], [Applause]
        text = re.sub(r'\(.*?\)', '', text) # Remove (Laughter)
        clean_text = text.strip()
        
        if not clean_text:
            continue
            
        formatted_transcript.append({
            "text": clean_text,
            "start": entry.start,
            "duration": entry.duration
        })
        full_text += clean_text + " "

    # Backend Sentence Processing
    full_text = full_text.strip()
    # Split by . ! ? while keeping the delimiters, then group into logical lines
    sentences = [s.strip() for s in re.split(r'(?<=[.!?])\s+', full_text) if s.strip()]

    print( {
        "video_id": video_id,
        "info": video_info,
        "transcript": formatted_transcript,
        "full_text": full_text,
        "sentences": sentences
    })
except Exception as e:
    raise print(e)
# Out:
# {'video_id': 'cESaIUWoCJQ', 'info': {'title': 'Unknown Title', 'thumbnail': 'https://img.youtube.com/vi/cESaIUWoCJQ/maxresdefault.jpg', 'author': 'Unknown Author'}, 'transcript': [{'text': 'Another day, another startup. Recently,', 'start': 0.0, 'duration': 5.04}, {'text': "I moved to Malaysia and from there, I've", 'start': 2.879, 'duration': 3.761}, {'text': 'pretty much been spending most of my', 'start': 5.04, 'duration': 3.92}, {'text': "time coding my latest project. And it's", 'start': 6.64, 'duration': 4.16}, {'text': 'been super fun hacking away at something', 'start': 8.96, 'duration': 3.36}, {'text': "new again. And luckily, I've been", 'start': 10.8, 'duration': 3.28}, {'text': 'documenting the whole journey from', 'start': 12.32, 'duration': 3.6}, {'text': 'coming up with the app idea to building', 'start': 14.08, 'duration': 3.6}, {'text': 'the app to getting that first paying', 'start': 15.92, 'duration': 3.519}, {'text': "customer. In this video, I'll show you", 'star
# ...

# %%
data = {
        "video_id": video_id,
        "info": video_info,
        "transcript": formatted_transcript,
        "full_text": full_text,
        "sentences": sentences
    }

print(json.dumps(data, indent=4))
# Out:
# {
#     "video_id": "cESaIUWoCJQ",
#     "info": {
#         "title": "Unknown Title",
#         "thumbnail": "https://img.youtube.com/vi/cESaIUWoCJQ/maxresdefault.jpg",
#         "author": "Unknown Author"
#     },
#     "transcript": [
#         {
#             "text": "Another day, another startup. Recently,",
#             "start": 0.0,
#             "duration": 5.04
#         },
#         {
#             "text": "I moved to Malaysia and from there, I've",
#             "start": 2.879,
#             "duration": 3.761
#         },
#         {
#             "text": "pretty much been spending most of my",
#             "start": 5.04,
#             "duration": 3.92
#         },
#         {
#             "text": "time coding my latest project. And it's",
#             "start": 6.64,
#             "duration": 4.16
#         },
#         {
#             "text": "been super fun hacking away at something",
#             "start": 8.96,
#             "duration": 3.36
#         },
# ...

# %%
text = response.text
text[:200]
# Out:
# '<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script'

# %%
from lxml import html
import requests
import json

# Parse the raw HTML text directly
tree = html.fromstring(response.text)

# Now you can use xpath
script_texts = tree.xpath('.//body/script/text()')
script_texts = script_texts[0].replace('var ytInitialPlayerResponse = ','')[:-1]
# data = json.loads(script_texts)
# print(data.keys())
script_texts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 import json
#       5 # Parse the raw HTML text directly
# ----> 6 tree = html.fromstring(response.text)
#       8 # Now you can use xpath
#       9 script_texts = tree.xpath('.//body/script/text()')
#
# NameError: name 'response' is not defined
